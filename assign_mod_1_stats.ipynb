# %% [markdown]
# #THEORY QUESTIONS

# %% [markdown]
# 1.What is statistics, and why is it important

# %% [markdown]
# Statistics is the scientific discipline concerned with collecting, organizing, analyzing, interpreting, and presenting data. It enables us to extract meaningful insights from data, facilitating informed decision-making across various domains.
#
# Why Is Statistics Important?
# Statistics plays a crucial role in numerous aspects of society and daily life:
#
# *   Informed Decision-Making: Governments, businesses, and organizations rely on statistical analyses to make evidence-based decisions. For instance, policymakers use statistical data to craft legislation and assess the impact of public programs.
#
# *   Scientific Research: In fields like medicine, genetics, and environmental science, statistics is fundamental for designing experiments, analyzing results, and validating findings. It helps researchers draw conclusions and advance knowledge.
#
# *   Everyday Applications: Statistics influence daily decisions, such as interpreting news reports, evaluating product reviews, or understanding health information. Statistical literacy empowers individuals to critically assess information and make better choices.
#
# *   Understanding Uncertainty and Variation: Statistical thinking allows us to comprehend and manage variability in processes and outcomes, which is essential in quality control, risk assessment, and forecasting.
#
# In summary, statistics is integral to comprehending complex data and making informed decisions in various facets of life, from public policy and scientific research to personal choices.

# %% [markdown]
# 2. What are the two main types of statistics

# %% [markdown]
# The two main branches of statistics are descriptive statistics and inferential statistics. Both are essential for analyzing and interpreting data, but they serve different purposes.
#
# 📊 Descriptive Statistics
# Descriptive statistics involve summarizing and organizing data to make it understandable. This includes calculating measures such as:
#
# *   Central tendency: mean, median, and mode
#
# *   Dispersion: range, variance, and standard deviation
#
# *   Frequency distributions: how often each value occurs
#
# *   Graphical representations: histograms, pie charts, and box plots
#
# These tools help describe the basic features of a dataset, providing simple summaries about the sample and the measures.
#
# 🔍 Inferential Statistics
# Inferential statistics involve making predictions or inferences about a population based on a sample of data drawn from that population. This includes techniques such as:
# Investopedia
#
# *   Hypothesis testing: determining if there is enough evidence to support a certain belief about a parameter
#
# *   Confidence intervals: estimating the range within which a population parameter lies
#
# *   Regression analysis: examining the relationship between variables
#
# *   Analysis of variance (ANOVA): comparing means among different groups
#
# These methods allow researchers to make conclusions that extend beyond the immediate data alone.

# %% [markdown]
# 3.What are descriptive statistics

# %% [markdown]
# Descriptive statistics is a branch of statistics that focuses on summarizing and organizing data to make it easily understandable. Unlike inferential statistics, which aims to make predictions or inferences about a population based on a sample, descriptive statistics simply describes the data at hand without making any assumptions beyond the dataset.
#
# 📊 Key Components of Descriptive Statistics
# Descriptive statistics can be categorized into several types:
#
# 1. Measures of Central Tendency
# These measures indicate the central point or typical value of a dataset:
#
# *   Mean: The average of all data points.
#
# *   Median: The middle value when data points are ordered.
#
# *   Mode: The most frequently occurring value in the dataset.
#
# 2. Measures of Dispersion (Variability)
# These measures describe the spread or variability within a dataset:
#
# *   Range: The difference between the highest and lowest values.
#
# *   Variance: The average of the squared differences from the mean.
#
# *   Standard Deviation: The square root of the variance, indicating how much data points deviate from the mean.
#
# *   Interquartile Range (IQR): The range between the first quartile (25th percentile) and the third quartile (75th percentile).
#
# 3. Measures of Frequency
# These measures show how often each value occurs:
#
# *   Frequency Distributions: Tables that display the frequency of various outcomes.
#
# *   Histograms: Bar graphs representing the frequency distribution of a dataset.
#
# 4. Measures of Position
# These measures indicate the relative position of data points within a dataset:
#
# *   Percentiles: Values below which a certain percentage of data falls.
#
# *   Quartiles: Values that divide the dataset into four equal parts.
#
# 📈 Visual Tools in Descriptive Statistics
# Visual representations are crucial for understanding data patterns:
#
# *   Bar Charts: Used for categorical data to show frequencies.
#
# *   Pie Charts: Depict proportions of categories within a whole.
#
# *   Box Plots: Display the distribution of data based on five-number summaries (minimum, first quartile, median, third quartile, and maximum).
#
# *   Histograms: Show the distribution of numerical data by grouping data into bins.
#
# 🧠 Importance of Descriptive Statistics
# Descriptive statistics are essential for:
#
# *   Data Summarization: Providing a quick overview of large datasets.
#
# *   Data Comparison: Comparing different datasets or groups within a dataset.
#
# *   Data Visualization: Creating visual representations to identify patterns, trends, and outliers.
#
# *   Foundation for Further Analysis: Serving as a preliminary step before conducting inferential statistics.
#
# In summary, descriptive statistics play a vital role in data analysis by offering tools to summarize and visualize data, making complex information more accessible and understandable

# %% [markdown]
# 4.What is inferential statistics

# %% [markdown]
# Inferential statistics is a branch of statistics that enables researchers to make predictions, draw conclusions, and generalize findings about a larger population based on data collected from a sample. It serves as a bridge between the data we have and the broader insights or hypotheses we want to explore about a larger group or population.
#
# 🔍 Key Concepts in Inferential Statistics
# 1. Sampling and Population
# Inferential statistics relies on analyzing a sample—a subset of the population—to make inferences about the entire population. By studying the sample, researchers aim to estimate population parameters and test hypotheses.
#
# 2. Hypothesis Testing
# This involves formulating a null hypothesis (a statement of no effect or difference) and an alternative hypothesis (indicating the presence of an effect or difference). Statistical tests, such as t-tests or chi-square tests, are used to determine whether the observed data provide sufficient evidence to reject the null hypothesis.
#
# 3. Confidence Intervals
# A confidence interval provides a range of values within which the true population parameter is expected to lie, with a certain level of confidence (e.g., 95%). It quantifies the uncertainty associated with a sample estimate.
# Simplilearn.com
#
# 4. Regression Analysis
# Regression analysis examines the relationship between variables, allowing researchers to model and predict outcomes. For example, linear regression can assess how changes in an independent variable affect a dependent variable.
#
# 5. Analysis of Variance (ANOVA)
# ANOVA tests whether there are statistically significant differences between the means of three or more groups. It's commonly used in experimental designs to assess the impact of different treatments or conditions.
#
# 📈 Applications of Inferential Statistics
#
# *   Market Research: Estimating customer satisfaction levels or preferences based on survey samples.
#
# *   Healthcare Studies: Determining the effectiveness of a new treatment by comparing patient outcomes in clinical trials.
#
# *   Public Policy: Assessing the impact of policy changes by analyzing data from affected populations.
#
# *   Education: Evaluating the effectiveness of teaching methods through student performance data.
#
# 🧠 Importance of Inferential Statistics
# *   Inferential statistics is crucial for making informed decisions when it's impractical or impossible to study an entire population. By analyzing sample data, researchers can draw conclusions, test theories, and make predictions that extend beyond the immediate data.

# %% [markdown]
# 5.What is sampling in statistics

# %% [markdown]
# In statistics, sampling is the process of selecting a subset of individuals, items, or observations from a larger group—known as the population—to estimate characteristics of the whole population. This approach is essential when studying the entire population is impractical due to constraints like time, cost, or accessibility. By analyzing a representative sample, researchers can make inferences about the broader population with a known level of confidence.
#
# 🔍 Why Sampling Matters
# *   Efficiency: Sampling allows for quicker data collection and analysis compared to surveying the entire population.
#
# *   Cost-effectiveness: It reduces the resources needed for data collection.
#
# *   Feasibility: In many cases, it's impossible to study every member of a population (e.g., all stars in the universe).
# Wikipedia
#
# *   Accuracy: When done correctly, sampling can provide accurate estimates of population parameters.
#
# 📚 Types of Sampling Methods
# Sampling methods are broadly categorized into two types:
#
# 1. Probability Sampling
# Every member of the population has a known, non-zero chance of being selected. This approach minimizes selection bias and allows for generalization of results.
#
# *   Simple Random Sampling: Each individual is chosen entirely by chance, ensuring each member has an equal probability of selection.
#
# *  Systematic Sampling: Selection of every kth individual from an ordered list, starting from a randomly chosen point.
# Wikipedia
#
# *  Stratified Sampling: The population is divided into subgroups (strata) based on shared characteristics, and random samples are taken from each stratum.
#
#
# *  Cluster Sampling: The population is divided into clusters, often based on geography or organization. Entire clusters are randomly selected, and all or a random sample of members from these clusters are studied.
#
# 2. Non-Probability Sampling
# Not all members have a known or equal chance of being selected. This method is often used when probability sampling isn't feasible.
# Scribbr
#
# *  Convenience Sampling: Selecting individuals who are easiest to reach.
# Scribbr
#
# *  Purposive (Judgmental) Sampling: Selecting individuals based on specific purposes or characteristics.
#
# *  Quota Sampling: Ensuring the sample meets certain quotas (e.g., 50% female, 50% male).
#
# *  Snowball Sampling: Existing study subjects recruit future subjects from among their acquaintances, useful for hard-to-reach populations.
# Wikipedia
#
# ⚠️ Potential Sampling Challenges
# Sampling Bias: Occurs when some members of the population are less likely to be included than others, leading to a non-representative sample.
# Scribbr
#
# *  Sampling Error: The natural variation that occurs by chance because a sample, rather than the entire population, is surveyed.
#
# *  Non-response Bias: When individuals selected for the sample do not respond, and their non-responses are not random.
#
# In summary, sampling is a fundamental aspect of statistical analysis, enabling researchers to make informed inferences about populations without examining every individual. Choosing the appropriate sampling method is crucial to ensure the validity and reliability of the study's findings.

# %% [markdown]
# 6. What are the different types of sampling methods

# %% [markdown]
# In statistics, sampling methods are techniques used to select a subset of individuals or observations from a larger population. These methods are broadly categorized into probability sampling and non-probability sampling, each with distinct approaches and applications.
#
# 🎯 Probability Sampling Methods
# In probability sampling, every member of the population has a known and non-zero chance of being selected. This approach enhances the representativeness of the sample and allows for generalizations to the broader population.
#
# *   Simple Random Sampling-
# Each individual is chosen entirely by chance, ensuring equal probability of selection.
# Example: Drawing names from a hat to select participants for a study.
# Best UPSC Coaching Centre in Hyderabad
#
# *   Systematic Sampling-
# Selection of every kth individual from an ordered list, starting from a randomly chosen point.
# Example: Selecting every 10th person on a customer list after a random start.
#
# *  Stratified Sampling-
# The population is divided into subgroups (strata) based on shared characteristics, and random samples are taken from each stratum.
# Example: Dividing a population by age groups and randomly sampling from each group to ensure age representation.
#
# *   Cluster Sampling-
# The population is divided into clusters, often based on geography or organization. Entire clusters are randomly selected, and all or a random sample of members from these clusters are studied.
# Example: Selecting entire schools within a district to survey students.
# Stats with R
#
# 🧪 Non-Probability Sampling Methods
# In non-probability sampling, not all members have a known or equal chance of being selected. This method is often used when probability sampling isn't feasible.
#
# *  Convenience Sampling-
# Selecting individuals who are easiest to reach.
# Example: Surveying people at a mall due to ease of access.
#
# *  Purposive (Judgmental) Sampling-
# Selecting individuals based on specific purposes or characteristics.
# Example: Choosing experts in a field for a specialized study.
#
# *  Quota Sampling-
# Ensuring the sample meets certain quotas (e.g., 50% female, 50% male).
# Example: Surveying a set number of participants from different income levels.
#
# *  Snowball Sampling-
# Existing study subjects recruit future subjects from among their acquaintances.
# Example: Studying a hidden population, like individuals with a rare disease, where participants refer others they know.
# Wikipedia
#
# 🧠 Choosing the Right Sampling Method
# *  The choice between these methods depends on factors like research objectives, population characteristics, resources, and the desired level of accuracy. Probability sampling is preferred for its ability to generalize findings, while non-probability sampling is useful for exploratory research or when probability sampling isn't practical.
#
# If you have a specific research context or population in mind, I can help you determine the most suitable sampling method for your needs.

# %% [markdown]
# 7.What is the difference between random and non-random sampling

# %% [markdown]
# The primary distinction between random sampling and non-random sampling lies in the method of selection and the implications for bias, representativeness, and generalizability.
#
# 🎯 Random Sampling (Probability Sampling)
# *   In random sampling, every member of the population has a known and equal chance of being selected. This approach minimizes selection bias and allows for statistical generalization to the broader population.
#
# Key Features:
#
# *   Equal Probability: Each individual has an equal chance of selection.
#
# *   Unbiased Selection: Reduces researcher influence on sample composition.
# SurveyPoint -
#
# *   Generalizability: Findings can be extrapolated to the entire population.
#
# *   Statistical Validity: Enables estimation of sampling error and confidence intervals.
#
# Common Methods:
#
# *   Simple Random Sampling: Random selection from the entire population.
#
# *   Systematic Sampling: Selecting every kth individual from a list.
#
# *   Stratified Sampling: Dividing the population into subgroups and sampling from each.
#
# *   Cluster Sampling: Randomly selecting entire groups or clusters.
#
# 🧪 Non-Random Sampling (Non-Probability Sampling)-
# *   In non-random sampling, selection is based on factors other than random chance, such as convenience or judgment. This method is often used when random sampling is impractical.
#
# Key Features:
#
# *   Unequal Probability: Not all individuals have a chance of selection.
# vedantu.com
#
# *   Potential Bias: Higher risk of selection bias due to subjective choices.
#
# *   Limited Generalizability: Findings may not represent the broader population.
# Neet Chennai
#
# *   Statistical Limitations: Difficult to estimate sampling error or apply inferential statistics.
#
# Common Methods:
#
# *   Convenience Sampling: Selecting individuals who are easily accessible.
#
# *   Purposive Sampling: Choosing individuals based on specific characteristics.
#
# *   Quota Sampling: Ensuring the sample meets certain predefined quotas.
#
# *   Snowball Sampling: Participants recruit other participants from their network
#
#
#
#
#
#
#
# 🧠 Choosing Between the Two
#
# Use Random Sampling when:
#
# *   The goal is to generalize findings to the entire population.
#
# *   Minimizing bias is crucial.
#
# *   Resources allow for comprehensive sampling methods.
#
# Use Non-Random Sampling when:
#
# *   Exploring specific subgroups or conducting preliminary research.
#
# *   Time or resources are limited.
#
# *   The population is hard to access or lacks a comprehensive list.
#
# Understanding the differences between these sampling methods is essential for designing effective studies and interpreting research findings accurately.

# %% [markdown]
# 8.Define and give examples of qualitative and quantitative data

# %% [markdown]
# | Feature          | Qualitative Data                              | Quantitative Data                             |                                                                                           |
# | ---------------- | --------------------------------------------- | --------------------------------------------- | ----------------------------------------------------------------------------------------- |
# | Nature           | Descriptive, non-numeric                      | Numeric, measurable                           |                                                                                           |
# | Data Type        | Categories, attributes                        | Counts, measurements                          |                                                                                           |
# | Analysis Methods | Thematic analysis, content analysis           | Statistical analysis, mathematical models     |                                                                                           |
# | Examples         | Interview responses, colors, emotions         | Test scores, height, temperature              |                                                                                           |
# | Data Collection  | Interviews, observations, open-ended surveys  | Surveys, experiments, structured observations |                                                                                           |
# | Use Cases        | Exploring concepts, understanding experiences | Testing hypotheses, measuring variables       |

# %% [markdown]
# 9.What are the different types of data in statistics

# %% [markdown]
# | Data Type        | Subtype    | Characteristics                                     | Examples                                    |                                                                                                                                                 |
# | ---------------- | ---------- | --------------------------------------------------- | ------------------------------------------- | ----------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Qualitative**  | Nominal    | Categories without order                            | Gender, blood type, marital status          |                                                                                                                                                 |
# |                  | Ordinal    | Categories with meaningful order                    | Education level, customer satisfaction      |                                                                                                                                                 |
# | **Quantitative** | Discrete   | Countable, distinct values                          | Number of children, cars owned, test scores |                                                                                                                                                 |
# |                  | Continuous | Measurable, infinite possible values within a range | Height, weight, temperature                 |

# %% [markdown]
# 10.Explain nominal, ordinal, interval, and ratio levels of measurement

# %% [markdown]
# | Level        | Order | Equal Intervals | True Zero | Mathematical Operations               | Examples                      |   |
# | ------------ | ----- | --------------- | --------- | ------------------------------------- | ----------------------------- | - |
# | **Nominal**  | No    | No              | No        | Equality                              | Gender, Blood Type            |   |
# | **Ordinal**  | Yes   | No              | No        | Equality, Order Comparison            | Education Level, Satisfaction |   |
# | **Interval** | Yes   | Yes             | No        | Equality, Order, Addition/Subtraction | Temperature, IQ Scores        |   |
# | **Ratio**    | Yes   | Yes             | Yes       | All Arithmetic Operations             | Height, Weight, Income        |   |

# %% [markdown]
# 11. What is the measure of central tendency

# %% [markdown]
# | Measure | Best Suited For                | Sensitivity to Outliers | Type of Data     |                                                                       |
# | ------- | ------------------------------ | ----------------------- | ---------------- | --------------------------------------------------------------------- |
# | Mean    | Symmetrical distributions      | High                    | Interval/Ratio   |                                                                       |
# | Median  | Skewed distributions           | Low                     | Ordinal/Interval |                                                                       |
# | Mode    | Categorical or multimodal data | None                    | Nominal/Ordinal  |
#
#
# Each measure provides unique insights into the data. The choice of which measure to use depends on the nature of the data and the specific analysis objectives.
#
#
#
# 1. Mean (Arithmetic Average)
# Definition: The mean is calculated by summing all the data values and dividing by the number of values.
#
# Formula:
# Mean
# =
# ∑
# 𝑋/
# 𝑁
#
#
# where:
#
# ∑
# 𝑋-
# *   ∑X is the sum of all data points.
#
# 𝑁-
# *   N is the number of data points.
#
#
# *   Usefulness: The mean is widely used and provides a comprehensive measure of central tendency. However, it is sensitive to extreme values (outliers), which can skew the result.
#
#
#
# 2) Median-
# *   Definition: The median is the middle value when the data points are arranged in ascending or descending order. If there is an even number of observations, the median is the average of the two middle numbers.
#
# *   Usefulness: The median is particularly useful when dealing with skewed distributions or outliers, as it is not affected by extreme values.
#
#
#
# 3) Mode-
# *   Definition: The mode is the value that appears most frequently in a dataset. A dataset may have one mode, more than one mode, or no mode at all.
#
#
# *   Usefulness: The mode is useful for categorical data where we wish to know which is the most common category.

# %% [markdown]
# 12. Define mean, median, and mode

# %% [markdown]
# | Measure | Best Suited For                | Sensitivity to Outliers | Type of Data     |                                                                       |
# | ------- | ------------------------------ | ----------------------- | ---------------- | --------------------------------------------------------------------- |
# | Mean    | Symmetrical distributions      | High                    | Interval/Ratio   |                                                                       |
# | Median  | Skewed distributions           | Low                     | Ordinal/Interval |                                                                       |
# | Mode    | Categorical or multimodal data | None                    | Nominal/Ordinal  |
#
#
# Each measure provides unique insights into the data. The choice of which measure to use depends on the nature of the data and the specific analysis objectives.
#
#
#
# 1. Mean (Arithmetic Average)
# Definition: The mean is calculated by summing all the data values and dividing by the number of values.
#
# Formula:
# Mean
# =
# ∑
# 𝑋/
# 𝑁
#
#
# where:
#
# ∑
# 𝑋-
# *   ∑X is the sum of all data points.
#
# 𝑁-
# *   N is the number of data points.
#
#
# *   Usefulness: The mean is widely used and provides a comprehensive measure of central tendency. However, it is sensitive to extreme values (outliers), which can skew the result.
#
#
#
# 2) Median-
# *   Definition: The median is the middle value when the data points are arranged in ascending or descending order. If there is an even number of observations, the median is the average of the two middle numbers.
#
# *   Usefulness: The median is particularly useful when dealing with skewed distributions or outliers, as it is not affected by extreme values.
#
#
#
# 3) Mode-
# *   Definition: The mode is the value that appears most frequently in a dataset. A dataset may have one mode, more than one mode, or no mode at all.
#
#
# *   Usefulness: The mode is useful for categorical data where we wish to know which is the most common category.

# %% [markdown]
# 13. What is the significance of the measure of central tendency

# %% [markdown]
# Measures of central tendency—mean, median, and mode—are fundamental statistical tools that summarize a dataset by identifying a central point around which data points tend to cluster. Their significance spans various fields, including business, education, healthcare, and social sciences, as they provide concise insights into data distributions and inform decision-making processes.
#
# 📌 Significance of Measures of Central Tendency
#
# Data Summarization-
#
# *   These measures condense large datasets into a single representative value, facilitating easier interpretation and comparison. For instance, reporting the average income of a population provides a snapshot of economic status without delving into individual variations.
#
# Comparison Across Groups-
#
# *   They enable comparisons between different groups or datasets. For example, comparing the average test scores (mean) of students from different schools can highlight educational disparities.
#
# Informed Decision-Making-
# *   In business and policy-making, understanding the central tendency helps in setting benchmarks, forecasting trends, and formulating strategies. For example, knowing the median age of a population can guide healthcare planning and resource allocation.
#
# Foundation for Further Analysis-
#
# *   They serve as the basis for more advanced statistical analyses. Measures like variance and standard deviation, which assess data spread, are often interpreted in conjunction with central tendency measures to provide a fuller picture of data distribution.
#
# Identification of Outliers-
#
# *   By comparing the central tendency with the actual data distribution, analysts can identify outliers or anomalies. For instance, a significantly higher mean compared to the median may indicate the presence of outliers skewing the data.
#
# Simplification of Complex Data-
#
# *   They transform complex datasets into understandable metrics, making it easier for stakeholders without statistical expertise to grasp key insights. For example, reporting the mode of customer preferences can help businesses understand the most popular product choices.
#
# In summary, measures of central tendency are indispensable in statistics for providing a clear, concise, and interpretable summary of data. They not only aid in understanding the central position of data but also lay the groundwork for more detailed statistical analyses and informed decision-making.
#
# If you have specific datasets or scenarios you'd like to explore, feel free to share, and I can assist in calculating and interpreting these measures for you.

# %% [markdown]
# 14.What is variance, and how is it calculated

# %% [markdown]
# Variance is a statistical measure that quantifies the degree of spread or dispersion in a dataset. It indicates how much individual data points differ from the mean (average) of the dataset. A higher variance signifies that data points are more spread out, while a lower variance indicates they are closer to the mean.
# Lifewire
#
# 📐 How to Calculate Variance
# There are two primary formulas for calculating variance: one for a population and another for a sample.
# CalculatorSoup
#
# 1. Population Variance
# When you have data for an entire population, the population variance is calculated using the formula:
#
# (given below)
#
# 2. Sample Variance
# When your data represents a sample from a larger population, the sample variance is calculated using the formula:
# (given below)
#
# 🔍 Significance of Variance
#
#
# *   Measure of Dispersion: Variance quantifies the extent to which data points deviate from the mean, providing insight into the variability within a dataset.
#
# *   Foundation for Other Metrics: Variance is a precursor to calculating the standard deviation, which is the square root of variance and is expressed in the same units as the data, making it more interpretable.
#
# *   Risk Assessment: In finance, variance is used to assess the volatility of asset returns. A higher variance indicates greater risk, while a lower variance suggests more stable returns.

# %% [markdown]
# ![Screenshot 2025-05-08 192612.png](data:image/png;base64,...)![Screenshot 2025-05-08 192556.png](data:image/png;base64,...)

# %% [markdown]
# 15.What is standard deviation, and why is it important

# %% [markdown]
# Standard deviation is a fundamental statistical measure that quantifies the amount of variation or dispersion in a dataset. It indicates how much individual data points deviate from the mean (average) of the dataset. A low standard deviation means the data points are close to the mean, while a high standard deviation indicates they are spread out over a wider range
#
#
#
# 🔍 Importance of Standard Deviation-
#
# *   Measure of Variability: Standard deviation provides a clear indication of how spread out the data points are around the mean. A higher standard deviation means greater variability, while a lower standard deviation indicates more consistency.
#
# *   Risk Assessment in Finance: In finance, standard deviation is used to measure the risk or volatility of an asset or portfolio. A higher standard deviation indicates higher risk, as the asset's returns are more spread out from the mean. Conversely, a lower standard deviation suggests more stable returns.
#
# *   Quality Control in Manufacturing: In manufacturing, standard deviation helps assess the consistency of products. A small standard deviation means products are consistently produced, while a large standard deviation may indicate issues in the production process.
#
# *   Scientific Research: In scientific experiments, standard deviation is used to understand the precision of measurements. Smaller standard deviations indicate more reliable and consistent results.
#
# *   Comparing Datasets: Standard deviation allows for comparison between different datasets. For example, two datasets may have the same mean but different standard deviations, indicating different levels of variability.

# %% [markdown]
# ![Screenshot 2025-05-08 193312.png](data:image/png;base64,...)![Screenshot 2025-05-08 193256.png](data:image/png;base64,...)

# %% [markdown]
# 16.Define and explain the term range in statistics

# %% [markdown]
# In statistics, range is a fundamental measure of variability that quantifies the spread of a dataset. It is calculated by subtracting the smallest value (minimum) from the largest value (maximum) in the dataset.
#
#
# 📐 How to Calculate the Range
# Identify the Maximum and Minimum Values: Determine the largest and smallest numbers in your dataset.
#
# *   Apply the Formula: Subtract the minimum value from the maximum value.
#
# Formula:
#
# Range=Maximum Value−Minimum Value
#
#
# 📊 Importance of Range
#
# *   Simplicity: The range is straightforward to calculate and provides a quick sense of the data's spread.
#
# *   Initial Analysis: It serves as a preliminary measure to understand the extent of variability in the dataset.
#
# *   Comparison Tool: Useful for comparing the spread of different datasets.
#
# ⚠️ Limitations of Range
# *   Sensitivity to Outliers: The range is highly influenced by extreme values, which can give a misleading impression of variability.
#
# *   Ignores Distribution: It does not account for how data points are distributed between the minimum and maximum values.
# Statistics Canada
#
# For a more robust measure of spread, consider using the interquartile range (IQR) or standard deviation, which provide deeper insights into data variability.

# %% [markdown]
# 17. What is the difference between variance and standard deviation

# %% [markdown]
# Variance and standard deviation are both measures of the spread or dispersion of a set of data points, but they differ in how they represent this spread:
#
#
# | **Feature**        | **Variance**                             | **Standard Deviation**                           |
# | ------------------ | ---------------------------------------- | ------------------------------------------------ |
# | **Formula**        | Squared differences from the mean        | Square root of variance                          |
# | **Units**          | Squared units of the data                | Same units as the data                           |
# | **Interpretation** | Less intuitive (in squared units)        | More intuitive (in same units as data)           |
# | **Purpose**        | Measures spread of data in squared terms | Measures spread in original units                |
# | **Magnitude**      | Can be much larger than the data itself  | Closer to the original data, easier to interpret
#
# Summary:
#
# *   Variance is useful for mathematical calculations and understanding data spread in squared units.
#
# *   Standard Deviation is more commonly used because it is in the same unit as the data and is more interpretable for most people.

# %% [markdown]
# ![Screenshot 2025-05-08 201018.png](data:image/png;base64,...)![Screenshot 2025-05-08 201000.png](data:image/png;base64,...)

# %% [markdown]
# 18.What is skewness in a dataset

# %% [markdown]
# Skewness is a statistical measure that describes the asymmetry of a dataset's distribution around its mean. It indicates whether the data points are symmetrically distributed or if they tend to lean towards one side.
#
# *   Types of Skewness:-
#
# Positive Skew (Right-Skewed):
#
# *   In a positively skewed distribution, the right tail (higher values) is longer or fatter than the left.
#
# *   This indicates that a majority of the data values are concentrated on the left, with a few extreme values stretching the tail to the right.
#
# *   The mean is typically greater than the median in such distributions.
#
#
# Negative Skew (Left-Skewed):
#
# *   In a negatively skewed distribution, the left tail (lower values) is longer or fatter than the right.
#
# *   This suggests that most data values are concentrated on the right, with some extreme low values extending the tail to the left.
#
# *   The mean is usually less than the median in these cases.
#
# Zero Skew (Symmetrical):
#
# *   A distribution with zero skewness is perfectly symmetrical.
#
# *   The left and right sides of the distribution are mirror images.
#
# *   The mean, median, and mode are all equal in such distributions.
# Number Analytics
#
# Importance of Skewness
#
# *   Understanding skewness is crucial because many statistical analyses assume normality (a symmetrical distribution). If data is skewed, these assumptions may not hold, potentially leading to inaccurate conclusions. For instance, in finance, skewness helps in assessing the risk of investments by indicating the likelihood of extreme returns.

# %% [markdown]
# 19.What does it mean if a dataset is positively or negatively skewed

# %% [markdown]
# In statistics, the terms positively skewed and negatively skewed describe the asymmetry of a dataset's distribution. Understanding the direction and degree of skewness is crucial for accurate data analysis and interpretation.
#
# 📈 Positively Skewed Distribution (Right-Skewed)-
#
# Definition: A positively skewed distribution has a longer tail on the right side. Most data points are concentrated on the left, with a few larger values stretching the tail to the right.
# Analytics Vidhya
#
# Characteristics:
#
# *   Mean > Median > Mode
#
# *   The right tail is longer than the left.
#
# *   Common in datasets where extreme high values are possible but rare.
#
# Example: Income distribution, where most people earn average wages, but a few earn exceptionally high incomes, leading to a right-skewed distribution.
#
# 📉 Negatively Skewed Distribution (Left-Skewed)-
#
# Definition: A negatively skewed distribution has a longer tail on the left side. Most data points are concentrated on the right, with a few smaller values stretching the tail to the left.
#
# Characteristics:
#
# *   Mean < Median < Mode
#
# *   The left tail is longer than the right.
#
# *   Common in datasets where extreme low values are possible but rare.
#
#
# Example: Age at retirement, where most people retire around the same age, but a few retire much earlier, leading to a left-skewed distribution.
#
# 🧠 Importance of Understanding Skewness
#
# *   Data Interpretation: Skewness affects the mean and median, influencing how we interpret the central tendency of the data.
#
# *   Statistical Analysis: Many statistical methods assume normality. Recognizing skewness helps in choosing appropriate methods or transforming data for analysis.
#
# *   Decision Making: In fields like finance, skewness indicates the likelihood of extreme outcomes, aiding in risk assessment and strategy development

# %% [markdown]
# 20.Define and explain kurtosis

# %% [markdown]
# Kurtosis is a statistical measure that describes the shape of a dataset's distribution, specifically focusing on the tails and the peak. It indicates the extent to which data points deviate from a normal distribution, particularly in terms of the frequency and extremity of outliers.
#
# 📐 Understanding Kurtosis
#
# Kurtosis assesses the "tailedness" of a distribution, revealing how much of the data lies in the tails (extreme values) compared to a normal distribution. A normal distribution has a kurtosis value of 3, often referred to as mesokurtic. Distributions with kurtosis greater than 3 are considered leptokurtic, indicating heavy tails and a higher likelihood of outliers. Conversely, distributions with kurtosis less than 3 are platykurtic, characterized by lighter tails and fewer outliers.
#
# 🔍 Types of Kurtosis-
#
# Mesokurtic:
#
# *   Kurtosis: Approximately 3
#
# *   Description: Distributions with kurtosis close to 3 resemble the normal distribution in terms of tail extremity and peak sharpness.
#
# *   Example: The normal distribution itself.
#
# Leptokurtic:
#
# *   Kurtosis: Greater than 3
#
# *   Description: These distributions have fatter tails and a sharper peak, indicating a higher probability of extreme values or outliers.
#
# *   Example: Financial returns data often exhibit leptokurtic distributions, where rare but significant events (like market crashes) occur more frequently than in a normal distribution.
#
# Platykurtic:
#
# *   Kurtosis: Less than 3
#
# *   Description: Platykurtic distributions have thinner tails and a flatter peak, suggesting fewer extreme values and a more uniform spread of data.
#
# *   Example: A uniform distribution, where all outcomes are equally likely, is platykurtic.
#
# 📊 Importance of Kurtosis
#
# *   Risk Assessment: In finance, understanding kurtosis helps in evaluating the risk of extreme events. Leptokurtic distributions, for instance, signal a higher chance of rare but impactful occurrences.
#
# *   Data Analysis: Kurtosis aids in identifying whether a dataset contains outliers or if the data is more uniformly distributed, influencing decisions on statistical methods and data transformations.
#
# *   Modeling Assumptions: Many statistical models assume normality. Recognizing deviations in kurtosis can inform adjustments to modeling techniques, ensuring more accurate analyses.

# %% [markdown]
# 21.What is the purpose of covariance

# %% [markdown]
# Covariance is a fundamental statistical measure that quantifies the directional relationship between two random variables. It indicates whether the variables tend to increase or decrease together, providing insight into their joint variability.
#
# 📘 What Is Covariance?
# Covariance measures how two variables change together. A positive covariance indicates that as one variable increases, the other tends to increase as well, and vice versa. Conversely, a negative covariance suggests that as one variable increases, the other tends to decrease. A covariance close to zero implies little to no linear relationship between the variables.
#
#
#
#
#
#
#
#
# 🔍 Purpose and Applications of Covariance
#
# Understanding Variable Relationships:
#
# *   Covariance helps determine whether two variables move in the same direction (positive covariance) or in opposite directions (negative covariance).
#
# Portfolio Management in Finance:
#
# *   In finance, covariance is used to assess how different assets move in relation to each other.
#
# *   A positive covariance between two assets indicates that they tend to move together, while a negative covariance suggests they move inversely.
#
# *   This information is crucial for portfolio diversification, as combining assets with negative covariance can reduce overall risk and volatility.
#
# Risk Assessment:
#
# *   Covariance aids in evaluating the risk associated with the combined movements of two variables, which is essential for making informed decisions in various fields, including economics and engineering.
#
# Basis for Correlation:
#
# *   Covariance is a foundational component in calculating the correlation coefficient, which standardizes the measure to a range between -1 and 1, making it easier to interpret the strength and direction of the relationship.
#
# ⚠️ Limitations of Covariance
#
#
# Magnitude Interpretation:
#
# *   The magnitude of covariance is not standardized, making it challenging to interpret the strength of the relationship without additional context or normalization.
# Investopedia
#
# Sensitivity to Units:
#
# *   Covariance is affected by the units of measurement of the variables, which can make comparisons across different datasets difficult.
#
# Not a Complete Measure:
#
# *   While covariance indicates the direction of the relationship, it does not provide information about the strength or significance of the relationship.
#
# In summary, covariance is a valuable statistical tool for understanding the directional relationship between two variables. While it provides insights into how variables move together, it should be used in conjunction with other measures, such as correlation, to gain a comprehensive understanding of the relationship.

# %% [markdown]
# ![Screenshot 2025-05-08 194926.png](data:image/png;base64,...)

# %% [markdown]
# 22. What does correlation measure in statistics

# %% [markdown]
# Correlation in statistics measures the strength and direction of a linear relationship between two variables. It quantifies how changes in one variable are associated with changes in another, without implying causation.
#
#
# 🔍 What Does Correlation Measure?
# Correlation assesses the degree to which two variables move together. A positive correlation indicates that as one variable increases, the other tends to increase as well. Conversely, a negative correlation suggests that as one variable increases, the other tends to decrease. A correlation close to zero implies little to no linear relationship between the variables.
#
# The most common measure of correlation is the Pearson correlation coefficient (r), which ranges from -1 to +1:
#
# *   r = +1: Perfect positive linear relationship
#
# *   r = 0: No linear relationship
#
# *   r = -1: Perfect negative linear relationship
#
# 📈 Types of Correlation
#
# *   Positive Correlation: Both variables increase or decrease together. For example, height and weight often have a positive correlation.
#
# *  Negative Correlation: One variable increases while the other decreases. For instance, the amount of gas in a tank and the distance traveled typically have a negative correlation.
#
# *   Zero or No Correlation: No predictable relationship exists between the variables. An example might be the relationship between shoe size and intelligence.
#
# 🧠 Importance of Correlation
#
# *   Predictive Insights: Identifying correlations can help in predicting one variable based on another.
#
# *   Risk Management: In finance, understanding correlations between assets aids in portfolio diversification and risk assessment.
#
# *   Scientific Research: Correlational studies can suggest relationships between variables, guiding further experimental research.
#
# ⚠️ Limitations-
#
# *   Correlation Does Not Imply Causation: Even if two variables are correlated, it doesn't mean that one causes the other.
#
# *   Sensitive to Outliers: Outliers can significantly affect the correlation coefficient, leading to misleading interpretations.
#
# *   Linear Relationships Only: Pearson's correlation measures only linear relationships; non-linear associations require different methods

# %% [markdown]
# 23.What is the difference between covariance and correlation

# %% [markdown]
# | Feature                  | Covariance                          | Correlation                             |                                                                                                                                              |
# | ------------------------ | ----------------------------------- | --------------------------------------- | -------------------------------------------------------------------------------------------------------------------------------------------- |
# | **Scale**                | Unbounded (can range from -∞ to +∞) | Bounded between -1 and +1               |                                                                                                                                              |
# | **Units**                | Units of $X$ × Units of $Y$         | Unitless                                |                                                                                                                                              |
# | **Interpretation**       | Direction of relationship           | Strength and direction of relationship  |                                                                                                                                              |
# | **Sensitivity to Scale** | Yes (affected by units)             | No (standardized)                       |                                                                                                                                              |
# | **Use Case**             | Portfolio theory, risk assessment   | Comparing relationships across datasets |
#
#
# 🧠 Summary
#
# *   Covariance: Indicates the direction of the linear relationship between two variables but lacks a standardized scale, making it less useful for comparing relationships across different datasets.
#
# *   Correlation: Provides both the strength and direction of the linear relationship between two variables, with a standardized scale, facilitating easier comparison across different datasets.
#
# Understanding both measures is crucial for analyzing and interpreting relationships between variables in various fields, including finance, economics, and data science.

# %% [markdown]
# ![Screenshot 2025-05-08 195743.png](data:image/png;base64,...)![Screenshot 2025-05-08 195728.png](data:image/png;base64,...)

# %% [markdown]
# 24. What are some real-world applications of statistics

# %% [markdown]
# Statistics is a powerful tool that permeates various aspects of daily life and professional fields. Here are some real-world applications of statistics:
#
# 🏥 Healthcare & Medicine
#
# *   Clinical Trials: Statistics are used to design and analyze clinical trials, determining the effectiveness of new treatments.
#
# *   Epidemiology: Statistical models help in understanding the spread of diseases and in planning public health responses.
#
# *   Medical Research: Analyzing patient data to identify risk factors and improve healthcare outcomes.
#
# 📈 Business & Economics
#
# *   Market Research: Businesses use statistics to understand consumer behavior, preferences, and market trends.
#
# *   Financial Analysis: Statistical methods are applied to assess investment risks, forecast economic conditions, and make informed financial decisions.
#
# *   Quality Control: Manufacturers employ statistical process control to monitor and improve product quality.
#
# 🏫 Education
#
# *   Student Assessment: Educational institutions use statistics to evaluate student performance and the effectiveness of teaching methods.
#
# *   Curriculum Development: Analyzing educational data to design curricula that meet the needs of students.
#
# ⚽ Sports
#
# *   Performance Analysis: Teams and coaches use statistics to analyze player performance and develop strategies.
#
# *   Fan Engagement: Analyzing fan behavior and preferences to enhance the spectator experience.
#
# 🌦️ Weather Forecasting
#
# *   Climate Modeling: Meteorologists use statistical models to predict weather patterns and understand climate change.
#
# *   Disaster Preparedness: Statistical data helps in planning for natural disasters and mitigating their impact.
#
# 🛡️ Insurance & Risk Management
#
# *   Premium Calculation: Insurance companies use statistical data to assess risk and determine premiums.
#
# *   Claims Analysis: Analyzing claims data to detect fraud and improve service.
# StatAnalytica
#
# 🗳️ Politics & Public Policy
#
# *   Election Forecasting: Statistical models predict election outcomes based on voting patterns and demographics.
#
# *   Policy Evaluation: Assessing the impact of policies through statistical analysis of public data.
#
# 🌱 Environmental Science
#
# *  Biodiversity Monitoring: Statistics are used to track species populations and biodiversity.
#
# *   Pollution Control: Analyzing environmental data to monitor and reduce pollution levels.
#
# 🧠 Psychology & Sociology
#
# *   Behavioral Studies: Statistical methods analyze human behavior, social trends, and cultural patterns.
#
# *   Survey Analysis: Interpreting survey data to understand public opinion and societal issues.
#
# Statistics is integral to decision-making processes across various sectors, providing insights that drive progress and innovation.

# %% [markdown]
# #PRACTICAL QUESTIONS

# %% [markdown]
#  1) How do you calculate the mean, median, and mode of a dataset

# %%
import numpy as np
from scipy import stats

data = [10, 20, 20, 30, 40, 50]

mean = np.mean(data)
median = np.median(data)


print(f"Mean: {mean}, Median: {median}")
# Out:
# Mean: 28.333333333333332, Median: 25.0

# %%
mode = stats.mode(data)[0]
print(f"Mode: {mode}")
# Out:
# Mode: 20

# %% [markdown]
# 2)  Write a Python program to compute the variance and standard deviation of a dataset

# %%
variance = np.var(data)
std_dev = np.std(data)

print(f"Variance: {variance}, Standard Deviation: {std_dev}")
# Out:
# Variance: 180.55555555555557, Standard Deviation: 13.43709624716425

# %% [markdown]
#  3) Create a dataset and classify it into nominal, ordinal, interval, and ratio types

# %%
nominal = ['Red', 'Blue', 'Green']
ordinal = ['Low', 'Medium', 'High']
interval = [10, 20, 30]
ratio = [1, 2, 3]

print("Nominal:", nominal)
print("Ordinal:", ordinal)
print("Interval:", interval)
print("Ratio:", ratio)
# Out:
# Nominal: ['Red', 'Blue', 'Green']
# Ordinal: ['Low', 'Medium', 'High']
# Interval: [10, 20, 30]
# Ratio: [1, 2, 3]

# %% [markdown]
# 4)  Implement sampling techniques like random sampling and stratified sampling

# %%
import pandas as pd

# Random Sampling
random_sample = np.random.choice(data, size=3, replace=False)

# Stratified Sampling
df = pd.DataFrame({'Age': [22, 25, 27, 35, 40, 45], 'Gender': ['M', 'F', 'M', 'F', 'M', 'F']})
strata = df.groupby('Gender')
stratified_sample = strata.apply(lambda x: x.sample(1))

print("Random Sample:", random_sample)
print("Stratified Sample:\n", stratified_sample)
# Out:
# Random Sample: [10 20 30]
# Stratified Sample:
#            Age Gender
# Gender
# F      1   25      F
# M      2   27      M
# <ipython-input-11-139e4173b3aa>:9: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   stratified_sample = strata.apply(lambda x: x.sample(1))

# %% [markdown]
# 5)  Write a Python function to calculate the range of a dataset

# %%
data_range = np.ptp(data)
print(f"Range: {data_range}")
# Out:
# Range: 40

# %% [markdown]
# 6) Create a dataset and plot its histogram to visualize skewness

# %%
import matplotlib.pyplot as plt

plt.hist(data, bins=5)
plt.title('Histogram')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# 7) Calculate skewness and kurtosis of a dataset using Python libraries

# %%
skewness = stats.skew(data)
kurt = stats.kurtosis(data)

print(f"Skewness: {skewness}, Kurtosis: {kurt}")
# Out:
# Skewness: 0.3053162697580519, Kurtosis: -1.151715976331361

# %% [markdown]
#  8) Generate a dataset and demonstrate positive and negative skewness

# %%
# Positive Skew
positive_skew = np.random.exponential(scale=2, size=100)

# Negative Skew
negative_skew = -np.random.exponential(scale=2, size=100)

plt.hist(positive_skew, bins=10, alpha=0.5, label='Positive Skew')
plt.hist(negative_skew, bins=10, alpha=0.5, label='Negative Skew')
plt.legend()
plt.show()

# %% [markdown]
# 9)  Write a Python script to calculate covariance between two datasets

# %%
data2 = [15, 25, 35, 45, 55,65]
cov_matrix = np.cov(data, data2)
print(f"Covariance Matrix:\n{cov_matrix}")
# Out:
# Covariance Matrix:
# [[216.66666667 270.        ]
#  [270.         350.        ]]

# %% [markdown]
#  10) Write a Python script to calculate the correlation coefficient between two datasets

# %%
correlation = np.corrcoef(data, data2)[0, 1]
print(f"Correlation Coefficient: {correlation}")
# Out:
# Correlation Coefficient: 0.9804686029234598

# %% [markdown]
#  11) Create a scatter plot to visualize the relationship between two variables

# %%
plt.scatter(data, data2)
plt.title('Scatter Plot')
plt.xlabel('Data')
plt.ylabel('Data2')
plt.show()

# %% [markdown]
# 12)  Implement and compare simple random sampling and systematic sampling

# %%
# Simple Random Sampling
simple_random = np.random.choice(data, size=3, replace=False)

# Systematic Sampling
step = 2
systematic_sample = data[::step]

print("Simple Random Sample:", simple_random)
print("Systematic Sample:", systematic_sample)
# Out:
# Simple Random Sample: [20 40 20]
# Systematic Sample: [10, 20, 40]

# %% [markdown]
#  13) Calculate the mean, median, and mode of grouped data

# %%
grouped_data = [(10, 2), (20, 3), (30, 5)]  # (value, frequency)
values, frequencies = zip(*grouped_data)

mean_grouped = np.average(values, weights=frequencies)
median_grouped = np.median(values)
mode_grouped = values[frequencies.index(max(frequencies))]

print(f"Mean: {mean_grouped}, Median: {median_grouped}, Mode: {mode_grouped}")
# Out:
# Mean: 23.0, Median: 20.0, Mode: 30

# %% [markdown]
# 14)  Simulate data using Python and calculate its central tendency and dispersion.

# %%
simulated_data = np.random.normal(loc=50, scale=10, size=1000)

mean_sim = np.mean(simulated_data)
median_sim = np.median(simulated_data)
std_dev_sim = np.std(simulated_data)

print(f"Simulated Mean: {mean_sim}, Median: {median_sim}, Standard Deviation: {std_dev_sim}")
# Out:
# Simulated Mean: 49.78242436284751, Median: 50.22197349264735, Standard Deviation: 10.389116265119192

# %% [markdown]
# 15) Use NumPy or pandas to summarize a dataset’s descriptive statistics

# %%
import pandas as pd

# Sample data
data = {'Age': [22, 25, 27, 35, 40, 45],
        'Salary': [22000, 25000, 27000, 35000, 40000, 45000]}

df = pd.DataFrame(data)

# Descriptive statistics
print(df.describe())
# Out:
#              Age        Salary
# count   6.000000      6.000000
# mean   32.333333  32333.333333
# std     9.114092   9114.091653
# min    22.000000  22000.000000
# 25%    25.500000  25500.000000
# 50%    31.000000  31000.000000
# 75%    38.750000  38750.000000
# max    45.000000  45000.000000

# %% [markdown]
#  16) Plot a boxplot to understand the spread and identify outliers

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sample data
data = [22, 25, 27, 35, 40, 45, 100]

# Create boxplot
sns.boxplot(data=data)
plt.title('Boxplot of Ages')
plt.show()

# %% [markdown]
#  17) Calculate the interquartile range (IQR) of a dataset

# %%
import numpy as np

# Sample data
data = [22, 25, 27, 35, 40, 45, 100]

# Calculate IQR
Q1 = np.percentile(data, 25)
Q3 = np.percentile(data, 75)
IQR = Q3 - Q1

print(f'IQR: {IQR}')
# Out:
# IQR: 16.5

# %% [markdown]
#  18) Implement Z-score normalization and explain its significance

# %%
import numpy as np

# Sample data
data = [22, 25, 27, 35, 40, 45]

# Calculate Z-scores
mean = np.mean(data)
std_dev = np.std(data)
z_scores = [(x - mean) / std_dev for x in data]

print(f'Z-scores: {z_scores}')
# Out:
# Z-scores: [np.float64(-1.2419887743332563), np.float64(-0.8814113882365046), np.float64(-0.6410264641720034), np.float64(0.32051323208600124), np.float64(0.9214755422472541), np.float64(1.522437852408507)]

# %% [markdown]
# 19)  Compare two datasets using their standard deviations

# %%
import numpy as np

# Sample data
data1 = [22, 25, 27, 35, 40]
data2 = [100, 105, 110, 115, 120]

# Calculate standard deviations
std_dev1 = np.std(data1)
std_dev2 = np.std(data2)

print(f'Standard Deviation of data1: {std_dev1}')
print(f'Standard Deviation of data2: {std_dev2}')
# Out:
# Standard Deviation of data1: 6.675327707311455
# Standard Deviation of data2: 7.0710678118654755

# %% [markdown]
#  20) Write a Python program to visualize covariance using a heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Sample data
data = np.array([[22, 22000],
                 [25, 25000],
                 [27, 27000],
                 [35, 35000],
                 [40, 40000]])

# Calculate covariance matrix
cov_matrix = np.cov(data, rowvar=False)

# Create heatmap
sns.heatmap(cov_matrix, annot=True, cmap='coolwarm', xticklabels=['Age', 'Salary'], yticklabels=['Age', 'Salary'])
plt.title('Covariance Matrix Heatmap')
plt.show()

# %% [markdown]
# 21)  Use seaborn to create a correlation matrix for a dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Sample data
data = {'Age': [22, 25, 27, 35, 40],
        'Salary': [22000, 25000, 27000, 35000, 40000]}

df = pd.DataFrame(data)

# Calculate correlation matrix
corr_matrix = df.corr()

# Create heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# 22)  Generate a dataset and implement both variance and standard deviation computations

# %%
import numpy as np

# Generate random data
data = np.random.normal(loc=50, scale=10, size=1000)

# Calculate variance and standard deviation
variance = np.var(data)
std_dev = np.std(data)

print(f'Variance: {variance}')
print(f'Standard Deviation: {std_dev}')
# Out:
# Variance: 106.63147022817452
# Standard Deviation: 10.32625150905083

# %% [markdown]
#  23) Visualize skewness and kurtosis using Python libraries like matplotlib or seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis
import numpy as np

# Sample data
data = np.random.normal(loc=0, scale=1, size=1000)

# Calculate skewness and kurtosis
data_skewness = skew(data)
data_kurtosis = kurtosis(data)

# Plot histogram
sns.histplot(data, kde=True)
plt.title(f'Skewness: {data_skewness:.2f}, Kurtosis: {data_kurtosis:.2f}')
plt.show()

# %% [markdown]
# 24)  Implement the Pearson and Spearman correlation coefficients for a dataset.

# %%
import numpy as np
from scipy.stats import pearsonr, spearmanr

# Sample data
x = np.array([22, 25, 27, 35, 40])
y = np.array([22000, 25000, 27000, 35000, 40000])

# Pearson correlation
pearson_corr, _ = pearsonr(x, y)

# Spearman correlation
spearman_corr, _ = spearmanr(x, y)

print(f'Pearson Correlation: {pearson_corr}')
print(f'Spearman Correlation: {spearman_corr}')
# Out:
# Pearson Correlation: 1.0
# Spearman Correlation: 0.9999999999999999
